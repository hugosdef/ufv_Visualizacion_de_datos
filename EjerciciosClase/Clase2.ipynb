# %% [markdown]
# <a href="https://colab.research.google.com/github/hugosdef/ufv_Visualizacion_de_datos/blob/main/EjerciciosClase/Clase2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
from IPython.display import display

# %%
uploaded = files.upload()

filename = list(uploaded.keys())[0]

dfVentas = pd.read_csv(filename, delimiter=';')
# Out:
#      <input type="file" id="files-9507a0c8-50b8-47de-b0a4-12453ea5bd0b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9507a0c8-50b8-47de-b0a4-12453ea5bd0b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dfVentas.head()
# Out:
#          COUNTRY        SUBBRAND  YEAR  MONTH     SCENARIO FORECAST  \
# 0       Portugal     Lipton (L3)  2023     12  AI_forecast  AI_P02F
# 1  Great Britain     Lipton (L3)  2023     12  AI_forecast  AI_P10F
# 2          Spain  Pepsi Max (L3)  2023     12  AI_forecast  AI_P09F
# 3  Great Britain        7up (L3)  2024     12  AI_forecast  AI_P10F
# 4        Hungary     Lipton (L3)  2023      9  AI_forecast  AI_P03F
#
#    FORECAST_YEAR    AMOUNT
# 0         2023.0  7,54E+15
# 1         2023.0  5,60E+15
# 2         2023.0  8,85E+15
# 3         2023.0  3,63E+15
# 4         2023.0  3,96E+16

# %% [markdown]
# Ej : P02F es el mes 1 es decir Enero.
# Year y month es hasta cuando es la predicción.

# %%
dfVentas.isna().sum()
# Out:
# COUNTRY            0
# SUBBRAND           0
# YEAR               0
# MONTH              0
# SCENARIO           0
# FORECAST         900
# FORECAST_YEAR    900
# AMOUNT             0
# dtype: int64

# %% [markdown]
# Nº de actual y forecast.

# %%
dfVentas['SCENARIO'].value_counts()
# Out:
# SCENARIO
# AI_forecast    17766
# actual           900
# Name: count, dtype: int64

# %% [markdown]
# Horizonte de precisión.

# %%
df = dfVentas
df[(df['FORECAST'] == 'AI_P10F') & (df['FORECAST_YEAR'] == 2023) & (df['COUNTRY'] == 'Portugal') & (df['SUBBRAND'] == 'Lipton (L3)')].sort_values(by=['YEAR', 'MONTH'])
# Out:
#         COUNTRY     SUBBRAND  YEAR  MONTH     SCENARIO FORECAST  \
# 1166   Portugal  Lipton (L3)  2023     10  AI_forecast  AI_P10F
# 1945   Portugal  Lipton (L3)  2023     11  AI_forecast  AI_P10F
# 2634   Portugal  Lipton (L3)  2023     12  AI_forecast  AI_P10F
# 6928   Portugal  Lipton (L3)  2024      1  AI_forecast  AI_P10F
# 5927   Portugal  Lipton (L3)  2024      2  AI_forecast  AI_P10F
# 18612  Portugal  Lipton (L3)  2024      3  AI_forecast  AI_P10F
# 5557   Portugal  Lipton (L3)  2024      4  AI_forecast  AI_P10F
# 16108  Portugal  Lipton (L3)  2024      5  AI_forecast  AI_P10F
# 16315  Portugal  Lipton (L3)  2024      6  AI_forecast  AI_P10F
# 909    Portugal  Lipton (L3)  2024      7  AI_forecast  AI_P10F
# 13342  Portugal  Lipton (L3)  2024      8  AI_forecast  AI_P10F
# 14310  Portugal  Lipton (L3)  2024      9  AI_forecast  AI_P10F
# 775    Portugal  Lipton (L3)  2024     10  AI_forecast  AI_P10F
# 1710   Portugal  Lipton (L3)  2024     11  AI_forecast  AI_P10F
# ...
